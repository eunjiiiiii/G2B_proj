# %% [markdown]
# ## 필요한 라이브러리 로드

# %%
import pandas as pd
import numpy as np

# %%
pd.options.display.float_format = '{:.5f}'.format

# %% [markdown]
# 금액과 관련된 변수를 지수형태로 나타나지 않게 위한 작업을 시행한다.

# %% [markdown]
# ## csv파일 데이터 로드 및 변수 선택

# %%
df_gg = pd.read_csv('/content/물품입찰공고.csv') #물품입찰공고 # 파일 경로 작성 필요
df_cf = pd.read_csv('/content/물품입찰분류별진행내역.csv') #물품입찰분류별진행내역 # 파일 경로 작성 필요

# %%
df_gg_features = df_gg[['등록유형','조달구분', '입찰공고번호', '품명내용', '긴급공고여부', '추정가격', '배정예산', 
                        '공동도급협정서접수방식', '입찰방식','낙찰자결정방법', '낙찰하한율']]

df_cf_features = df_cf[['입찰공고번호', '합계수량', '낙찰자결정여부', '낙찰업체투찰률', '낙찰업체투찰금액', '낙찰자결정적용법규', '기초금액', '참가수']]

# %% [markdown]
# 모델링 전 전처리 과정에서 실제로 null값을 가진 값을 drop, data의 value 대체 등 조건을 걸어 전처리를 진행한 변수들만 선택하였다.

# %%
df_2 = pd.merge(df_gg_features, df_cf_features, how='inner', on='입찰공고번호')

# %%
df = df_2.copy()

# %% [markdown]
# merge를 통하여 두 가지 csv파일에서 변수를 선택한 후 입찰공고번호를 기준으로 inner join하여 하나의 데이터프레임으로 합병한다.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 108349 entries, 0 to 108348
# Data columns (total 18 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   등록유형         108349 non-null  object
#  1   조달구분         108349 non-null  object
#  2   입찰공고번호       108349 non-null  int64
#  3   품명내용         108348 non-null  object
#  4   긴급공고여부       91583 non-null   object
#  5   추정가격         105957 non-null  float64
#  6   배정예산         104871 non-null  float64
#  7   공동도급협정서접수방식  108147 non-null  object
#  8   입찰방식         108349 non-null  object
#  9   낙찰자결정방법      106851 non-null  object
#  10  낙찰하한율        64600 non-null   float64
#  11  합계수량         108349 non-null  float64
#  12  낙찰자결정여부      108349 non-null  object
#  13  낙찰업체투찰률      85136 non-null   float64
#  14  낙찰업체투찰금액     85136 non-null   float64
#  15  낙찰자결정적용법규    101608 non-null  object
#  16  기초금액         67274 non-null   float64
#  17  참가수          85136 non-null   float64
# dtypes: float64(8), int64(1), object(9)
# memory usage: 15.7+ MB

# %% [markdown]
# ## data 전처리

# %%
df = df[df['등록유형'] == '나라장터(G2B)']
df = df.drop(['등록유형'], axis=1)

# %% [markdown]
# 등록유형을 나라장터로 한정하고, 등록유형을 drop한다.

# %%
df = df.dropna(subset=['품명내용'])
df = df.dropna(subset=['긴급공고여부'])
df = df.dropna(subset=['추정가격'])
df = df.dropna(subset=['배정예산'])

# %% [markdown]
# 품명내용, 긴급공고여부, 추정가격, 배정예산이 na인 값은 대체가 불가능하므로 drop한다.

# %%
df = df[df['입찰방식'].str.contains('전자')]
df = df.drop(['입찰방식'], axis=1)

df.head(3)
# Out:
#    조달구분       입찰공고번호                 품명내용  ... 낙찰자결정적용법규            기초금액      참가수
# 0  중앙조달  20210121987  액체크로마토그래프[41115705]  ...     국가계약법             NaN  2.00000
# 1  자체조달  20210123012        전광판[55121903]  ...     지방계약법  56070000.00000 19.00000
# 2  자체조달  20210123612       곡류가루[50221102]  ...     지방계약법 685227840.00000  4.00000
#
# [3 rows x 16 columns]

# %% [markdown]
# 전자입찰과 관련된 입찰방식으로 추린다.

# %%
df['낙찰하한율'].isna().sum() #낙찰하한율 대체 전
# Out:
# 23603

# %% [markdown]
# null값의 대체가 가능한 낙찰하한율은 대체한다.

# %%
df[(df['낙찰자결정방법'].isna()==True) & (df['낙찰하한율'].isna()==False)][['낙찰자결정방법', '낙찰하한율']]
# Out:
#        낙찰자결정방법    낙찰하한율
# 400        NaN 87.99500
# 1096       NaN 90.00000
# 3164       NaN 87.99500
# 3972       NaN 88.00000
# 4125       NaN 87.99500
# ...        ...      ...
# 106535     NaN 87.99500
# 106622     NaN 87.99500
# 107751     NaN 90.00000
# 108029     NaN 87.99500
# 108035     NaN 87.99500
#
# [217 rows x 2 columns]

# %% [markdown]
# 낙찰자결정방법을 통해 낙찰하한율을 대체할 예정이다. 그러나 낙찰자결정방법이 결측치인 데이터를 모두 제거하면, 낙찰자결정방법은 결측이지만 낙찰하한율은 결측이 아닌 데이터까지 제거하게 되므로 낙찰하한율이 있는 경우에는 낙찰자결정방법을 drop하지 않는다.

# %%
df['낙찰자결정방법'] = df['낙찰자결정방법'].fillna('알수없음')

# %%
df.loc[df['낙찰자결정방법'].str.contains('10억이상'), '낙찰하한율'] = 80.495
df.loc[df['낙찰자결정방법'].str.contains('10억원이상'), '낙찰하한율'] = 80.495

df.loc[df['낙찰자결정방법'].str.contains('10억원미만'), '낙찰하한율'] = 80.495
df.loc[df['낙찰자결정방법'].str.contains('10억미만'), '낙찰하한율'] = 80.495

df.loc[df['낙찰자결정방법'].str.contains('고시금액미만'), '낙찰하한율'] = 84.245
df.loc[df['낙찰자결정방법'].str.contains('고시금액 미만'), '낙찰하한율'] = 84.245

df.loc[df['낙찰자결정방법'].str.contains('간행물'), '낙찰하한율'] = 89.995

# %% [markdown]
# 낙찰하한율을 대체할 수 있는 정보가 한정적이여서 많이 대체하지는 못했지만, 정보가 업데이트 된다면 모델을 업데이트 할 필요가 있어보임.

# %%
df['낙찰하한율'].isna().sum() #낙찰하한율 대체 후
# Out:
# 23063

# %% [markdown]
# 낙찰하한율의 null값의 개수가 감소하였음.

# %%
df = df.dropna(subset=['낙찰하한율'])

# %% [markdown]
# 낙찰하한율의 나머지 null값은 처리가 불가능하므로 drop한다.

# %%
df = df.dropna(subset=['기초금액'])
df = df.dropna(subset=['추정가격'])
df = df.dropna(subset=['낙찰업체투찰금액'])

# %% [markdown]
# 금액과 관련된 변수는 대체 시 data상의 오류가 발생할 가능성이 있으므로 null값을 drop한다.

# %% [markdown]
# 금액과 관련된 변수는 null값이 없어야 하며 대체도 불가능하다.

# %%
df = df.dropna(subset=['합계수량'])
df = df.dropna(subset=['낙찰자결정적용법규'])
df = df.dropna(subset=['공동도급협정서접수방식'])
df = df.dropna(subset=['참가수'])
df = df[df['조달구분']=='자체조달']

df.head(3)
# Out:
#    조달구분       입찰공고번호                  품명내용  ... 낙찰자결정적용법규            기초금액      참가수
# 1  자체조달  20210123012         전광판[55121903]  ...     지방계약법  56070000.00000 19.00000
# 2  자체조달  20210123612        곡류가루[50221102]  ...     지방계약법 685227840.00000  4.00000
# 3  자체조달  20210123753  생고기또는생새고기류[50111598]  ...     지방계약법  92930000.00000  5.00000
#
# [3 rows x 16 columns]

# %% [markdown]
# 합계수량과 낙찰자 결정 적용 법규, 공동도급 협정서 접수 방식, 참가수를 다른 값으로 대체한다면 data상의 오류가 발생할 가능성이 있다. 따라서 drop하고, EDA 당시 중앙조달의 data 수가 매우 적어 가격 예측에 도움이 되지 못할 것 같아 자체조달로 한정하였으므로 자체조달로 한정한다.

# %%
df = df[df['낙찰업체투찰금액'] != 0]

# %% [markdown]
# 낙찰업체투찰금액이 0원인 값은 Null로 간주하여 0원을 제거한다.

# %%
Q1 = np.percentile(df['낙찰업체투찰금액'].values, 25)
Q3 = np.percentile(df['낙찰업체투찰금액'].values, 75)

IQR = Q3-Q1

df = df[(df['낙찰업체투찰금액'] >= (Q1 - (1.5*IQR))) & (df['낙찰업체투찰금액'] <= (Q3 + (1.5*IQR)))]

# %% [markdown]
# 낙찰업체투찰금액의 편차가 매우 크므로, 이상치를 제거한다.

# %%
df = df[df['낙찰하한율'] >= 79]

df.head(3)
# Out:
#    조달구분       입찰공고번호                    품명내용  ... 낙찰자결정적용법규           기초금액       참가수
# 1  자체조달  20210123012           전광판[55121903]  ...     지방계약법 56070000.00000  19.00000
# 3  자체조달  20210123753    생고기또는생새고기류[50111598]  ...     지방계약법 92930000.00000   5.00000
# 7  자체조달  20210124885  상온보관우유또는버터제품[50131702]  ...     지방계약법      430.00000 224.00000
#
# [3 rows x 16 columns]

# %% [markdown]
# 낙찰하한율이 79% 이하인 것은 이상치로 판단하고 79 이상인 것들로만 간추린다.

# %%
df.loc[df['낙찰자결정방법'].str.contains('적격심사'), '낙찰자결정방법'] = '적격심사낙찰제'
df.loc[df['낙찰자결정방법'].str.contains('최저가'), '낙찰자결정방법'] = '최저가낙찰제'
df.loc[df['낙찰자결정방법'].str.contains('계약이행능력심사'), '낙찰자결정방법'] = '계약이행능력심사'
df.loc[df['낙찰자결정방법'].str.contains('희망수량경쟁'), '낙찰자결정방법'] = '희망수량경쟁'

df.낙찰자결정방법.value_counts()
# Out:
# 최저가낙찰제      31023
# 적격심사낙찰제      6990
# 계약이행능력심사     1527
# 알수없음           34
# 희망수량경쟁         19
# Name: 낙찰자결정방법, dtype: int64

# %% [markdown]
# 낙찰자 결정방법의 명칭을 통일한다.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39593 entries, 1 to 108331
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   조달구분         39593 non-null  object
#  1   입찰공고번호       39593 non-null  int64
#  2   품명내용         39593 non-null  object
#  3   긴급공고여부       39593 non-null  object
#  4   추정가격         39593 non-null  float64
#  5   배정예산         39593 non-null  float64
#  6   공동도급협정서접수방식  39593 non-null  object
#  7   낙찰자결정방법      39593 non-null  object
#  8   낙찰하한율        39593 non-null  float64
#  9   합계수량         39593 non-null  float64
#  10  낙찰자결정여부      39593 non-null  object
#  11  낙찰업체투찰률      39593 non-null  float64
#  12  낙찰업체투찰금액     39593 non-null  float64
#  13  낙찰자결정적용법규    39593 non-null  object
#  14  기초금액         39593 non-null  float64
#  15  참가수          39593 non-null  float64
# dtypes: float64(8), int64(1), object(7)
# memory usage: 5.1+ MB

# %% [markdown]
# data의 전처리는 진행되었으므로, 필요한 변수를 제외하고 전부 삭제한다.

# %%
df = df[['합계수량', '기초금액', '추정가격', '낙찰하한율', '낙찰업체투찰금액']]

df.head(3)
# Out:
#           합계수량           기초금액           추정가격    낙찰하한율       낙찰업체투찰금액
# 1      1.00000 56070000.00000 50972727.00000 88.00000 49439300.00000
# 3      1.00000 92930000.00000 84481818.00000 84.24500 78410000.00000
# 7 205700.00000      430.00000 80410000.00000 84.24500      363.28000

# %% [markdown]
# 전처리용 column을 제외하고, 실제 모델링에 필요한 변수들만 간추린다.

# %%
df['개당기초금액'] = df['기초금액'] / df['합계수량']
df['개당추정가격'] = df['추정가격'] / df['합계수량']
df['개당낙찰업체투찰금액'] = df['낙찰업체투찰금액'] / df['합계수량']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df.head(3)
# Out:
#           합계수량           기초금액  ...         개당추정가격     개당낙찰업체투찰금액
# 1      1.00000 56070000.00000  ... 50972727.00000 49439300.00000
# 3      1.00000 92930000.00000  ... 84481818.00000 78410000.00000
# 7 205700.00000      430.00000  ...      390.90909        0.00177
#
# [3 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# 합계수량          0
# 기초금액          0
# 추정가격          0
# 낙찰하한율         0
# 낙찰업체투찰금액      0
# 개당기초금액        0
# 개당추정가격        0
# 개당낙찰업체투찰금액    0
# dtype: int64

# %% [markdown]
# 각 data마다 합계수량의 차이가 있으므로, 금액과 관련된 변수를 합계수량으로 나누어 개당 금액을 구한다.

# %% [markdown]
# # Mini Project(경고창으로 입찰 성공률 높이기)

# %% [markdown]
# 나라장터에서 다양한 공고의 개찰 결과를 확인했을 때, 낙찰하한선 미달, 예가 초과와 같은 이유로 심사에서 탈락한 경우를 확인했다. 특히, 나라장터를 이용한 공공조달을 처음 이용하는 개인이나 기업의 입장에서 투찰금액을 제시하는 방법을 몰라 심사에서 탈락하는 경우가 많을 것이라 예상된다. 따라서, 나라장터를 처음 이용하거나, 입찰 경험이 없는 사람들을 위해 제시한 투찰금액이 낙찰하한선 미달이나 예가 초과의 가능성이 있을 경우, 경고창을 띄어 입찰 가능성을 높일 수 있다는 기대를 하였다.

# %%
df_check = df.copy() # Mini project에 사용할 데이터프레임 생성.

# %%
df_check.reset_index(drop=True, inplace=True) # index를 내림차순으로 새로 설정하였다.

# %%
df_check.drop(['합계수량'], axis=1, inplace=True)
# 사용할 변수를 제외한 나머지 변수를 drop한다.

# %% [markdown]
# 기초금액을 이용한 예정가격 산정 순서
# 1. 기초금액을 기준으로 98%~102% 사이의 복수예가 15개 생성
# 2. 복수예가 15개 중 추첨을 통해 4개 선택
# 3. 선택된 4개의 숫자를 산술평균하여 예정가격 산정

# %% [markdown]
# 위 과정을 코드로 작성하여 기초금액을 통해 예정가격을 예측하였다.

# %%
import random

lists=[]
for j in range(0, len(df_check)):  
    for i in range(1, 16):
        number = [random.uniform(df_check['개당기초금액'][j]*0.98, df_check['개당기초금액'][j]*1.02)] # +-2% 범위 내에서 15개의 난수 생성
        select = np.random.choice(number, 4) # 15개의 난수 중 임의로 4개 선택
        average = np.mean(select) # 선택한 4개 숫자의 산술평균: 예정가격
    lists.append(average)

# %%
df_check['예정가격_pred'] = lists # 예측된 예정가격을 '예정가격_pred' column에 저장하였다.

# %%
df_check['낙찰하한선_pred'] = df_check['예정가격_pred'] * df_check['낙찰하한율'] * 0.01

# %%
df_check['낙찰하한선_기초'] = df_check['개당기초금액'] * df_check['낙찰하한율'] * 0.01

# %%
df_check['낙찰하한선_추정'] = df_check['개당추정가격'] * df_check['낙찰하한율'] * 0.01

# %% [markdown]
# 예정가격은 입찰 공고 단계에서 확인할 수 없으므로 우리가 사용할 수 없는 볍수다. 따라서 기초금액을 통해 예정가격을 직접 예측해보고 이를 통해 낙찰하한선 미달과 예가초과의 범위를 시험해볼 것이다.

# %% [markdown]
# 크게 3가지 Case로 구분해서 test할 것이다.
# 1.   직접 구한 예정가격을 이용한 test
# 2.   기초금액을 이용한 test
# 3.   추정가격을 이용한 test

# %%
df_check.head()
# Out:
#             기초금액           추정가격  ...       낙찰하한선_기초       낙찰하한선_추정
# 0 56070000.00000 50972727.00000  ... 49341600.00000 44855999.76000
# 1 92930000.00000 84481818.00000  ... 78288878.50000 71171707.57410
# 2      430.00000 80410000.00000  ...        0.00176      329.32136
# 3      430.00000      430.00000  ...        0.00249        0.00249
# 4      430.00000      430.00000  ...        0.00183        0.00183
#
# [5 rows x 11 columns]

# %% [markdown]
# 1. 직접 구한 예정가격을 이용한 test

# %%
count=0
for i in range(0, len(df)):
    if df_check['낙찰하한선_pred'][i] > df_check['개당낙찰업체투찰금액'][i]: # 낙찰하한선 미달
        count+=1
print(count)
        #print('경고: {}번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.'.format(i))
# Out:
# 13181

# %%
count=0
for i in range(0, len(df)):
    if df_check['예정가격_pred'][i] < df_check['개당낙찰업체투찰금액'][i]: # 예가초과
        count+=1
print(count)
        #print('경고: {}번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.'.format(i))
# Out:
# 528

# %% [markdown]
# 예정가격은 기초금액의 +-2%내에서 생성된 난수를 통해 산정되기 때문에 새로운 예정가격이 산정될 때 마다 test 값이 달라진다. 다만, 어느정도 범위가 한정되어 있어 오차값이 크지는 않다.

# %% [markdown]
# 2. 기초금액을 이용한 test

# %%
count=0
for i in range(0, len(df)):
    if df_check['낙찰하한선_기초'][i] > df_check['개당낙찰업체투찰금액'][i]: # 낙찰하한선 미달
        count+=1
print(count)
        #print('경고: {}번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.'.format(i))
# Out:
# 12357

# %%
count=0
for i in range(0, len(df)):
    if df_check['개당기초금액'][i] < df_check['개당낙찰업체투찰금액'][i]: # 예가초과
        count+=1
print(count)
        #print('경고: {}번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.'.format(i))
# Out:
# 17

# %% [markdown]
# 3. 추정가격을 이용한 test

# %%
count=0
for i in range(0, len(df)):
    if df_check['낙찰하한선_추정'][i] > df_check['개당낙찰업체투찰금액'][i]: # 낙찰하한선 미달
        count+=1
print(count)
        #print('경고: {}번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.'.format(i))
# Out:
# 5553

# %%
count=0
for i in range(0, len(df)):
    if df_check['개당추정가격'][i] < df_check['개당낙찰업체투찰금액'][i]: # 예가초과
        count+=1
print(count)
        #print('경고: {}번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.'.format(i))
# Out:
# 7586

# %% [markdown]
# Result

# %% [markdown]
# 추정가격은 기초금액이나 예정가격에 비해 과하게 측정되는 경우가 많다. 따라서 낙찰하한선 미달의 경우에는 좋은 결과를 보여주지만 예가초과의 경우에는 좋지 않는 결과를 보여준다. 따라서, 추정가격을 사용하는 것은 옳지 않다고 본다.

# %% [markdown]
# 기초금액과 직접 구한 예정가격을 비교해보면, 기초금액의 결과가 조금 더 좋은 것을 확인할 수 있다. 하지만, 기초금액을 통해 낙찰하한선 미달과 예가 초과를 예측하는 것은 사실상 쉽지 않다. 그리고 우리가 사용한 데이터는 대략 4만개 정도 이므로 매우 적은 수치다. 더 많은 데이터를 사용한다면 예정가격을 사용했을 때 더 좋은 결과를 보일 수도 있을 것이라 판단되므로 Mini project에서는 예정가격을 사용하기로 결론 짓는다.

# %% [markdown]
# # Final Code

# %%
df_check = df.copy() # Mini project에 사용할 데이터프레임 생성.

df_check.reset_index(drop=True, inplace=True) # index를 내림차순으로 새로 설정하였다.

df_check.drop(['합계수량'], axis=1, inplace=True)
# 사용할 변수를 제외한 나머지 변수를 drop한다.

# %%
import random

lists=[]
for j in range(0, len(df_check)):  
    for i in range(1, 16):
        number = [random.uniform(df_check['개당기초금액'][j]*0.98, df_check['개당기초금액'][j]*1.02)] # +-2% 범위 내에서 15개의 난수 생성
        select = np.random.choice(number, 4) # 15개의 난수 중 임의로 4개 선택
        average = np.mean(select) # 선택한 4개 숫자의 산술평균: 예정가격
    lists.append(average)

# %%
df_check['예정가격_pred'] = lists # 예측된 예정가격을 '예정가격_pred' column에 저장하였다.
df_check['낙찰하한선_pred'] = df_check['예정가격_pred'] * df_check['낙찰하한율'] * 0.01

# %%
for i in range(0, len(df)):
    if df_check['낙찰하한선_pred'][i] > df_check['개당낙찰업체투찰금액'][i]: # 낙찰하한선 미달
        print('경고: {}번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.'.format(i))
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 경고: 24124번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24125번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24129번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24134번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24136번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24138번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24142번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24143번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24144번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24145번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24149번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24150번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24156번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24158번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24159번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24160번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24164번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24168번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24170번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24174번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24187번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24188번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24190번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24195번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24205번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24208번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24211번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24214번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24217번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24219번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24222번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24224번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24231번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24233번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24236번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24247번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24248번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24250번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24251번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24255번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24257번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24258번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24260번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24261번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24262번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24265번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24268번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24282번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24289번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24297번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24304번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24306번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24309번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24310번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24311번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24324번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24328번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24329번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24333번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24336번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24338번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24342번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24350번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24355번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24356번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24357번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24369번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24370번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24375번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24377번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24379번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24380번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24381번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24384번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24385번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24389번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24390번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24393번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24399번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24400번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24405번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24409번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24410번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24414번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24415번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24420번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24422번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24427번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24429번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24438번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24444번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24449번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24450번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24451번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24453번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24458번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24459번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24467번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24481번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24483번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24487번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24491번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24496번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24497번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24498번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24499번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24500번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24501번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24504번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24506번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24509번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24510번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24511번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24513번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24515번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24518번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24523번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24524번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24531번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24533번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24538번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24541번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24542번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24558번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24567번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24572번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24575번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24576번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24577번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24578번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24582번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24583번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24586번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24596번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24598번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24604번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24605번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24606번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24607번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24608번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24609번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24611번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24613번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24616번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24618번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24622번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24623번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24626번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24628번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24630번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24631번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24632번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24634번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24649번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24650번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24651번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24657번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24659번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24661번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24675번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24683번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24688번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24691번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24696번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24700번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24702번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24704번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24706번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24708번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24715번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24716번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24717번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24718번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24728번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24730번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24731번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24735번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24737번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24740번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24742번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24745번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24753번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24759번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24760번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24762번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24763번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24769번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24771번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24774번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24775번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24776번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24778번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24792번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24794번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24796번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24798번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24803번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24805번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24811번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24814번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24818번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24819번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24825번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24826번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24827번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24830번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24833번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24834번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24843번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24847번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24849번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24851번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24853번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24859번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24861번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24862번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24866번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24868번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24869번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24874번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24875번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24876번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24878번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24879번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24880번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24883번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24884번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24885번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24888번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24890번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24891번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24896번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24898번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24901번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24903번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24905번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24906번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24907번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24909번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24910번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24912번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24914번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24917번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24922번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24923번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24924번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24936번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24938번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24939번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24940번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24944번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24947번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24952번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24957번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24960번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24962번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24963번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24964번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24973번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24978번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24981번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24984번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24987번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24992번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24996번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25002번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25004번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25007번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25008번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25013번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25015번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25017번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25022번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25034번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25036번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25037번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25038번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25042번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25046번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25051번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25057번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25063번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25064번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25067번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25068번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25073번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25076번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25077번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25079번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25082번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25084번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25085번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25106번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25107번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25108번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25109번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25115번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25124번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25132번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25133번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25135번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25140번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25153번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25155번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25156번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25159번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25165번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25167번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25178번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25181번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25182번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25183번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25184번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25186번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25187번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25191번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25193번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25204번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25207번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25208번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25210번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25211번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25212번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25215번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25217번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25218번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25223번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25224번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25226번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25228번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25229번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25234번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25239번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25252번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25253번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25255번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25256번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25260번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25261번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25263번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25266번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25267번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25271번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25274번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25279번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25287번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25289번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25294번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25295번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25297번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25298번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25301번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25305번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25308번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25312번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25313번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25316번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25317번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25323번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25324번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25325번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25327번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25331번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25336번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25346번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25350번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25351번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25357번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25358번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25360번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25361번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25366번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25367번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25368번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25370번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25376번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25378번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25379번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25381번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25382번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25387번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25390번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25392번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25396번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25404번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25412번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25422번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25424번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25428번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25429번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25431번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25432번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25433번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25437번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25440번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25441번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25449번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25450번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25452번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25454번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25457번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25465번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25470번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25472번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25473번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25478번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25481번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25482번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25483번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25488번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25492번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25493번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25495번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25506번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25507번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25508번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25509번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25511번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25512번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25516번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25517번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25524번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25525번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25537번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25540번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25541번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25543번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25549번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25550번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25551번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25552번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25554번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25562번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25565번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25566번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25568번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25570번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25576번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25578번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25581번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25586번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25588번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25593번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25600번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25607번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25609번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25611번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25614번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25615번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25616번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25617번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25618번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25619번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25625번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25626번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25627번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25628번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25631번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25633번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25640번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25647번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25650번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25651번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25655번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25657번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25659번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25663번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25668번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25672번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25674번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25675번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25677번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25680번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25683번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25686번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25687번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25694번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25695번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25698번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25700번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25703번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25704번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25705번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25706번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25707번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25710번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25713번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25715번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25717번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25718번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25720번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25724번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25725번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25729번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25731번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25735번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25738번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25743번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25745번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25746번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25748번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25753번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25755번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25756번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25759번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25760번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25762번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25767번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25770번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25772번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25775번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25778번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25780번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25783번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25784번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25786번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25787번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25795번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25798번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25801번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25802번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25804번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25805번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25808번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25813번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25818번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25820번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25826번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25827번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25828번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25833번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25835번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25836번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25838번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25842번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25844번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25849번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25856번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25858번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25861번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25864번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25867번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25868번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25872번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25877번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25884번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25888번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25901번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25906번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25908번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25914번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25915번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25916번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25921번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25924번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25925번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25927번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25928번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25930번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25943번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25948번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25949번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25956번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25964번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25967번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25970번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25972번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25976번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25977번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25981번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25982번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25987번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25989번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25990번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25994번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25995번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25996번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25999번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26002번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26007번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26014번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26015번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26016번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26019번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26026번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26031번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26033번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26034번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26035번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26036번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26037번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26039번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26042번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26047번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26052번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26056번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26058번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26061번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26064번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26065번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26070번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26071번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26072번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26074번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26076번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26080번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26085번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26086번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26089번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26090번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26091번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26094번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26095번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26096번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26099번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26101번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26106번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26108번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26119번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26121번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26124번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26125번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26126번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26128번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26131번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26132번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26135번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26136번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26137번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26141번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26145번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26148번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26150번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26154번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26155번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26158번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26168번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26176번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26183번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26187번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26189번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26195번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26196번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26199번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26206번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26210번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26212번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26216번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26221번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26229번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26236번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26237번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26243번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26248번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26249번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26255번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26258번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26260번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26263번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26265번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26267번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26271번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26273번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26279번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26281번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26286번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26291번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26292번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26293번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26294번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26302번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26305번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26310번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26311번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26313번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26314번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26315번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26321번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26323번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26325번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26326번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26327번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26332번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26333번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26334번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26335번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26336번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26339번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26343번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26344번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26345번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26350번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26354번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26358번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26366번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26369번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26371번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26372번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26378번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26379번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26380번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26383번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26386번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26398번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26402번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26404번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26405번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26408번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26409번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26411번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26414번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26416번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26418번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26419번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26420번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26422번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26423번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26427번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26428번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26431번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26437번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26440번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26442번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26445번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26447번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26450번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26471번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26474번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26475번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26476번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26481번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26491번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26492번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26493번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26494번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26498번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26501번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26503번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26506번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26513번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26518번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26519번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26521번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26525번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26529번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26531번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26532번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26536번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26546번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26549번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26552번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26555번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26560번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26563번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26564번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26577번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26579번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26582번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26588번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26589번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26591번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26592번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26593번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26597번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26601번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26605번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26608번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26611번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26614번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26618번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26625번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26626번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26629번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26632번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26633번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26634번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26635번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26637번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26649번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26660번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26662번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26664번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26665번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26666번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26667번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26668번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26670번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26672번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26676번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26681번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26683번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26684번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26686번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26687번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26690번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26692번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26693번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26695번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26696번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26699번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26707번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26710번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26713번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26721번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26722번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26724번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26725번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26727번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26729번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26734번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26741번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26742번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26748번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26750번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26751번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26756번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26760번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26765번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26768번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26769번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26772번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26776번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26778번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26780번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26781번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26782번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26788번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26790번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26795번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26801번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26803번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26804번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26805번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26811번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26812번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26816번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26819번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26820번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26821번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26824번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26825번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26835번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26836번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26848번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26853번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26859번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26861번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26864번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26865번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26866번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26870번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26871번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26872번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26874번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26880번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26887번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26890번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26892번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26899번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26900번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26901번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26910번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26913번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26925번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26929번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26931번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26932번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26936번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26941번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26947번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26948번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26951번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26952번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26954번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26959번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26964번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26967번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26968번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26969번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26974번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26981번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26983번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26984번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26987번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26989번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26990번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26997번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27001번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27007번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27011번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27014번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27021번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27026번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27027번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27028번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27029번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27033번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27036번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27037번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27039번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27040번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27043번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27044번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27046번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27047번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27052번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27054번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27057번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27058번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27059번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27060번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27064번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27065번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27067번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27069번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27073번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27076번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27077번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27080번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27082번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27086번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27087번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27090번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27091번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27095번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27099번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27100번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27106번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27116번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27117번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27118번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27123번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27128번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27129번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27130번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27140번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27145번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27147번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27148번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27149번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27162번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27164번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27170번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27173번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27175번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27176번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27180번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27184번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27188번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27189번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27194번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27195번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27202번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27203번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27204번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27205번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27207번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27210번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27212번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# ...
# 경고: 38613번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38615번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38616번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38622번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38623번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38628번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38631번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38634번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38638번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38639번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38647번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38648번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38651번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38653번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38654번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38660번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38666번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38669번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38670번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38671번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38672번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38677번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38681번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38683번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38686번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38695번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38696번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38698번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38715번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38721번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38723번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38724번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38725번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38730번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38731번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38732번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38736번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38737번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38746번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38752번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38759번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38762번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38763번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38768번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38771번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38774번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38777번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38779번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38782번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38785번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38789번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38790번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38791번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38792번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38794번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38796번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38802번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38805번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38809번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38820번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38826번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38829번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38831번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38832번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38834번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38842번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38844번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38847번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38849번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38865번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38867번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38869번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38873번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38874번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38879번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38881번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38882번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38885번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38888번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38890번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38891번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38895번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38901번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38905번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38907번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38908번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38910번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38914번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38922번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38925번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38928번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38932번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38934번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38943번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38944번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38947번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38948번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38951번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38955번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38956번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38959번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38960번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38961번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38962번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38966번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38967번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38977번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38980번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38982번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38986번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38987번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38989번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38990번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38992번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38995번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39001번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39005번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39006번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39008번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39009번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39012번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39014번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39017번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39019번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39025번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39026번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39029번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39030번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39035번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39038번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39040번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39044번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39058번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39059번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39060번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39062번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39064번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39065번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39071번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39072번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39078번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39079번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39082번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39084번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39088번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39090번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39093번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39100번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39105번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39106번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39107번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39112번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39116번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39119번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39120번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39123번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39124번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39125번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39126번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39130번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39138번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39141번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39145번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39148번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39158번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39159번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39162번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39163번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39164번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39165번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39169번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39174번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39175번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39176번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39178번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39182번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39184번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39186번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39187번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39188번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39193번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39196번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39197번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39198번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39201번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39202번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39205번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39206번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39207번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39210번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39211번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39221번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39223번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39224번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39226번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39229번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39234번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39235번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39236번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39238번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39240번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39241번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39248번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39257번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39259번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39260번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39266번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39267번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39271번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39276번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39277번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39279번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39280번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39281번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39283번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39285번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39287번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39288번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39296번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39297번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39304번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39306번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39308번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39313번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39316번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39318번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39320번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39322번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39323번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39324번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39325번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39327번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39329번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39333번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39337번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39339번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39348번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39349번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39351번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39353번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39363번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39364번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39367번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39368번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39370번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39371번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39373번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39375번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39376번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39378번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39382번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39387번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39389번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39397번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39398번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39402번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39406번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39409번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39412번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39413번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39415번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39421번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39426번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39427번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39429번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39432번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39435번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39436번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39437번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39439번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39443번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39444번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39446번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39450번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39451번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39453번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39459번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39462번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39463번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39466번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39468번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39470번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39471번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39473번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39475번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39481번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39485번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39486번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39487번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39489번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39490번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39491번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39496번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39499번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39501번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39502번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39504번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39509번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39516번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39520번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39521번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39526번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39528번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39533번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39534번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39537번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39543번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39544번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39546번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39547번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39553번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39555번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39564번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39574번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39578번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39582번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39586번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39587번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39588번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39590번째 투찰금액은 낙찰하한선 미달이므로 이후 심사에서 탈락할 수 있습니다.

# %%
for i in range(0, len(df)):
    if df_check['예정가격_pred'][i] < df_check['개당낙찰업체투찰금액'][i]: # 예가초과
        print('경고: {}번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.'.format(i))
# Out:
# 경고: 41번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 282번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 447번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 536번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 554번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 677번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 765번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 814번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 1122번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 1187번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 1201번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 1202번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 1215번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 1304번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 1329번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 2072번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 2209번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 2293번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 2327번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 2372번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 2616번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 2625번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 2632번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 2932번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 2978번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 3019번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 3060번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 3150번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 3240번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 3463번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 3525번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 3605번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 3953번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 4253번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 4338번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 4501번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 4527번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 4532번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 4554번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 4695번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 4722번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 4932번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 5036번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 5321번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 5372번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 5401번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 5412번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 5449번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 5795번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 5838번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 5840번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 5928번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 6030번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 6070번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 6097번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 6140번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 6275번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 6525번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 6703번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 6746번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 6777번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 6801번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 6818번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 6826번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 7033번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 7077번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 7241번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 7259번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 7301번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 7557번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 7587번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 7604번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 7717번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 7754번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 7760번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 7770번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 7878번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 7940번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 7973번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 8248번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 8313번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 8379번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 8412번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 8418번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 8455번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 8635번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 8636번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 8639번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 8640번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 8646번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 8647번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 8656번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 8660번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 8661번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 8662번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 8704번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 8822번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 8825번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 8860번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 8891번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 8898번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 8921번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 8992번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 8993번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 8996번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 9057번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 9098번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 9171번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 9229번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 9333번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 9345번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 9444번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 9506번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 9525번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 9557번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 9561번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 9699번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 9720번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 9745번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 9752번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 9768번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 9769번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 9823번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 9911번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 10161번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 10325번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 10791번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 10936번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 10995번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 11208번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 11315번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 11406번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 11538번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 11600번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 11685번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 11849번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 11960번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 12057번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 12211번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 12235번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 12473번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 12592번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 12782번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 12797번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 13025번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 13246번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 13281번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 13397번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 13525번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 13613번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 13927번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 13938번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 13965번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 14061번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 14121번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 14131번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 14233번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 14341번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 14374번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 14406번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 14606번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 14626번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 14645번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 14764번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 14966번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 15059번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 15205번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 15207번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 15323번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 15325번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 15401번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 15446번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 15488번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 15493번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 15667번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 15691번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 15739번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 15783번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 15823번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 15824번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 15826번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 15836번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 15839번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 15840번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 15986번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 16012번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 16085번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 16103번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 16151번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 16396번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 16406번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 16538번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 16692번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 16693번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 16803번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 16878번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 16944번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 17067번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 17184번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 17224번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 17271번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 17376번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 17410번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 17565번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 17612번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 17657번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 17660번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 17724번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 17751번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 17761번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 17814번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 17851번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 17868번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 18090번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 18129번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 18176번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 18186번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 18278번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 18440번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 18580번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 18592번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 18668번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 18700번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 18744번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 18811번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 18853번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 18867번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 18933번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 18937번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 18975번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 19097번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 19122번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 19133번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 19299번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 19300번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 19301번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 19303번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 19309번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 19591번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 19722번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 19756번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 19825번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 19866번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 19970번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 20005번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 20060번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 20230번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 20235번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 20381번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 20521번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 20758번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 20765번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 20824번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 21034번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 21200번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 21649번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 22053번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 22063번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 22078번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 22160번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 22249번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 22474번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 22500번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 22561번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 22566번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 22570번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 22621번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 22702번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 22879번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 23343번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 23389번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 23462번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 23532번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 23595번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 23624번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 23835번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 23845번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24022번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24110번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24157번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24177번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24191번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24435번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24475번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24652번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24671번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24705번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24720번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24799번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 24871번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25097번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25100번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25101번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25102번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25104번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25213번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25296번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25322번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25447번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25459번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25580번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25643번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25869번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25958번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 25979번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26009번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26028번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26151번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26156번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26223번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26278번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26360번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26439번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26456번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26540번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26571번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26580번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26682번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26717번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26731번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26851번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26852번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26909번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 26991번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27208번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27376번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27466번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27538번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27630번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27631번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27685번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27729번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27817번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27828번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27873번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27918번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27922번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 27995번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 28153번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 28255번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 28293번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 28348번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 28450번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 28464번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 28553번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 28674번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 28763번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 28770번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 28780번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 28816번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 28817번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 28821번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 28827번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 28906번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 28920번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 29068번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 29221번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 29222번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 29300번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 29368번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 29391번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 29492번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 29822번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 29824번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 29825번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 29827번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 30069번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 30147번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 30288번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 30451번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 30497번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 30571번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 30673번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 30755번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 30842번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 31109번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 31183번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 31207번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 31349번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 31419번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 31435번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 31446번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 31548번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 31738번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 31825번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 31894번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 31985번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 32056번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 32095번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 32118번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 32131번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 32163번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 32236번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 32270번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 32471번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 32564번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 32580번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 32754번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 32802번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 32884번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 32916번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 32982번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 33009번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 33013번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 33047번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 33050번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 33167번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 33176번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 33253번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 33323번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 33329번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 33382번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 33404번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 33503번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 33859번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 34092번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 34172번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 34177번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 34359번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 34566번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 34704번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 34730번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 34827번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 34830번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 34833번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 34845번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 34898번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 34971번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 35116번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 35127번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 35147번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 35154번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 35180번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 35182번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 35247번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 35303번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 35399번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 35463번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 35615번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 35659번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 35706번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 35819번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 35834번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 35898번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 35973번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 36034번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 36136번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 36143번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 36384번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 36427번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 36441번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 36448번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 36454번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 36455번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 36542번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 36543번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 36640번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 36689번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 36709번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 36716번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 36760번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 36848번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 36852번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 36912번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 37144번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 37182번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 37343번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 37475번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 37574번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 37623번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 37765번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 37790번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 37798번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 37883번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 37887번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38027번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38128번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38190번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38219번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38241번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38296번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38298번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38300번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38302번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38304번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38305번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38307번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38309번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38311번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38382번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38489번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38507번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38508번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38514번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38515번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38576번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38604번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38664번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38689번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38712번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38828번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38845번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38896번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38979번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 38983번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39172번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39250번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39299번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39419번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39456번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39540번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39581번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
# 경고: 39589번째 투찰금액은 예가 초과이므로 이후 심사에서 탈락할 수 있습니다.
